# %% [markdown]
# このNotebookは、このイメージにインストールされたライブラリ/ツールが予期した通りにインストールされていることをチェックするものです。Travis CI上でpapermillにより実行されます。
#
# This notebooks tests whether the installed apps work expectedly, and can be executed by papermill on Travis CI.

# %% [markdown]
# # Libraries

# %% [markdown]
# numpy and matplotlib to draw charts

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 10.0, 0.1)
plt.plot(x, np.sin(x))

# %% [markdown]
# pandas to display tables

# %%
import pandas as pd

pd.DataFrame([(0, 1), (2, 3)], columns=['A', 'B'])
# Out:
#    A  B
# 0  0  1
# 1  2  3

# %% [markdown]
# # Utilities

# %%
# !which ansible
# Out:
# /usr/local/bin/ansible

# %%
# !which wget
# Out:
# /usr/bin/wget

# %%
# !which curl
# Out:
# /usr/bin/curl

# %%
# !which papermill
# Out:
# /usr/local/bin/papermill

# %%
# !sudo ls
# Out:
# 01_02_AWSインスタンス起動例.ipynb
# 01_03_Set_Inventory.ipynb
# 12_s3fsのインストール-提供用.ipynb
# 13_s3fsのマウント-提供用.ipynb
# 20171004_02_Spark+2.1.1とR講義環境のインストール.ipynb
# 20171005_02_Spark+HDFS設定変更.ipynb
# 20180112_01_転送用fluentdの設定・起動.ipynb
# 20180118_01_Jenkins設定と起動-Aラック.ipynb
# 20180327_01_納品用Notebookまとめ.ipynb
# 20180606_01_syslog-fluentdコンテナの設定と起動-iusv0002,iusv0004.ipynb
# 20180920_04_D06_minikube-setup-nb05.ipynb
# 20180921_05_D15_JupyterHub-settings-nb05.ipynb
# 20190208_01_法定停電対応(停止).ipynb
# 20190212_01_法定停電対応(起動).ipynb
# 98_Test python2 env.ipynb
# 99_Test python3 env.ipynb
# cloudop-c.zip
# cloudop.zip
# coursewarehub-20181030
# hosts
# lc-notebook-diff-0.1.0.tar.gz
# topse-20181105
# Untitled.ipynb
# VMの新規作成 中井さん 1.ipynb
# VMの新規作成 中井さん 2.ipynb
# VMの新規作成 中井さん 3.ipynb
# 可視化サンプル-ike-marge.ipynb
# 既存マシンをAnsibleで操作可能にする.ipynb
# 既存マシンをAnsibleで操作可能にする-o.ipynb
