# %% [markdown]
# このNotebookは、このイメージにインストールされたライブラリ/ツールが予期した通りにインストールされていることをチェックするものです。Travis CI上でpapermillにより実行されます。
#
# This notebooks tests whether the installed apps work expectedly, and can be executed by papermill on Travis CI.

# %%
import sys
assert sys.version_info[0] == 3

# %% [markdown]
# # Libraries

# %% [markdown]
# numpy and matplotlib to draw charts

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 10.0, 0.1)
plt.plot(x, np.sin(x))

# %% [markdown]
# pandas to display tables

# %%
import pandas as pd

pd.DataFrame([(0, 1), (2, 3)], columns=['A', 'B'])
# Out:
#    A  B
# 0  0  1
# 1  2  3

# %% [markdown]
# # Utilities

# %%
# !which ansible
# Out:
# /usr/local/bin/ansible

# %%
# !which wget
# Out:
# /usr/bin/wget

# %%
# !which curl
# Out:
# /usr/bin/curl

# %%
# !which papermill
# Out:
# /usr/local/bin/papermill

# %%
# !sudo ls
# Out:
# 01_About NII Extensions - NII謹製の機能拡張について.ipynb  images
# 02_AWS操作用ツールのインストール.ipynb			   README.md
# 98_Test python2 env.ipynb				   resources
# 99_Test python3 env.ipynb
